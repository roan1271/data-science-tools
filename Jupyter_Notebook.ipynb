# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Tools for Data Science</h1>

# %% [markdown]
# <h5>Welcome to my notebook, here you can find a summary of the basics of data science tools.</h5>

# %% [markdown]
# Common data science languages:
# - Python
# - R
# - Scala
# - Julia
# - Java

# %% [markdown]
# Data science libraries:
# - scikit-learn
# - matplotlib
# - ggplot2
# - keras

# %% [markdown]
# Table of Data Science tools:
#
# | Tool name         | Some languages used  |
# | ------------      | -------------------- |
# | Jupyter Notebooks | Python, R and more   |
# | Apache Hadoop     | Java                 |
# | Apache Spark      | Scala                |
# | Scikit-learn      | Python               |
# | Tensorflow        | Python, R            |

# %% [markdown]
# <h4>Examples of Arithmetic Expressions:</h4>

# %%
x=5*4
y=6+4
z=x+y
final=x*y+z
print(final)
# Out:
# 230

# %%
minutes = 180
hours = minutes/60
print(hours)
# Out:
# 3.0

# %% [markdown]
# <h4>Objectives:</h4>
# Using markdown and code cells to:
#
# - List down data science languages and libraries
# - Code arithmetic calculations
# - Code conversion from minutes to hours

# %% [markdown]
# Author name: <strong>Roan Varghese</strong>
